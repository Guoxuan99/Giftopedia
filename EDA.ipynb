# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.multioutput import MultiOutputClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix, ConfusionMatrixDisplay, classification_report
from utils import confusion_matrix, data_preprocessing
import utils
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime

# %%
df = data_preprocessing(pd.read_csv("data/Demographic to Gift Preference Survey.csv"))

# %%
df_1 = df.iloc[:,0:12]
df_2 = df.iloc[:,21:33]
print(np.sum(df_1))
print(np.sum(df_2))
new_df = pd.concat([df_1,df_2],axis=1)
corr = new_df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# Height (cm)                                                      20028.5
# Weight (kg)                                                       6821.7
# Age                                                               2701.0
# Relationship Period                                              30648.0
# h_Arts & Crafts (embroidery, knitting, drawing)                     40.0
# h_Collecting (stamps, coins)                                         6.0
# h_Games (board and computer games)                                  67.0
# h_Model & Electronic (tinkering electronics, cars)                  14.0
# h_Music (performing or listening)                                   94.0
# h_Performing Arts (drawing, sculpting, cooking)                     40.0
# h_Spiritual and Mental (meditation, self-enrichment sessions)       31.0
# h_Sports & Outdoors (e-sports doesn't count)                        74.0
# dtype: float64
# g_Accompaniment (Pets, etc..)                   12
# ...

# %%
df_1 = df.iloc[:,13:21]
df_2 = df.iloc[:,21:33]
print(np.sum(df_1))
new_df = pd.concat([df_1,df_2],axis=1)
corr = new_df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# m_Comedy      87.0
# m_Drama       61.0
# m_Fantasy     43.0
# m_Horror      35.0
# m_Mystery     60.0
# m_Romance     58.0
# m_Thriller    33.0
# m_Western     23.0
# dtype: float64
# <style  type="text/css" >
# #T_4d377_row0_col0,#T_4d377_row1_col1,#T_4d377_row2_col2,#T_4d377_row3_col3,#T_4d377_row4_col4,#T_4d377_row5_col5,#T_4d377_row6_col6,#T_4d377_row7_col7,#T_4d377_row8_col8,#T_4d377_row9_col9,#T_4d377_row10_col10,#T_4d377_row11_col11,#T_4d377_row12_col12,#T_4d377_row13_col13,#T_4d377_row14_col14,#T_4d377_row15_col15,#T_4d377_row16_col16,#T_4d377_row17_col17,#T_4d377_row18_col18,#T_4d377_row19_col19{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_4d377_row0_col1,#T_4d377_row0_col3,#T_4d377_row8_col1{
#             background-color:  #6f92f3;
#             color:  #000000;
# ...

# %%
df_1 = df.iloc[:,34:45]
df_2 = df.iloc[:,21:33]
print(np.sum(df_1))
new_df = pd.concat([df_1,df_2],axis=1)
corr = new_df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# Horoscope_Aries (Mar 21-Apr 19)          11
# Horoscope_Cancer (Jun 21-Jul 22)         15
# Horoscope_Capricorn (Dec 22-Jan 19)       9
# Horoscope_Gemini (May 21-Jun 20)          9
# Horoscope_Leo (July 23-Aug 22)            7
# Horoscope_Libra (Sep 23-Oct 22)           5
# Horoscope_Pisces (Feb 19-Mar 20)          6
# Horoscope_Sagittarius (Nov 22-Dec 21)     7
# Horoscope_Scorpio (Oct 23-Nov 21)        18
# Horoscope_Taurus (Apr 20-May 20)         15
# Horoscope_Virgo (Aug 23-Sep 22)           9
# dtype: int64
# <style  type="text/css" >
# ...

# %%
df_1 = df.iloc[:,45:64]
df_2 = df.iloc[:,21:33]
print(np.sum(df_1))
new_df = pd.concat([df_1,df_2],axis=1)
corr = new_df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# Body State_Fat                                                  1
# Body State_Lean                                                 1
# Body State_Muscular                                             5
# Body State_Normal                                              87
# Body State_Not slim                                             1
# Body State_Slightly overweight                                  1
# Body State_Slim                                                25
# Relationship Status_Single                                     94
# Relationship Status_relationship                               27
# Hometown _East Coast Region: Kelantan, Terengganu, Pahang,     20
# Hometown _East Malaysia: Sabah, Sarawak                         4
# Hometown _Northern Region: Perlis, Kedah, Penang, Perak.       61
# Hometown _Others                                                2
# Hometown _Southern Region: Negeri Sembilan, Malacca, Johor.    21
# ...
